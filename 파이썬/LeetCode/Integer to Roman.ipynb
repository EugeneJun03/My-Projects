# %% [markdown]
# ### 12. Integer to Roman
# - Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# Symbol   :    Value
#
# I         :    1
#
# V          :   5
#
# X           :  10
#
# L            : 50
#
# C             :100
#
# D        :     500
#
# M         :    1000
#
# For example, 2 is written as II in Roman numeral, just two one's added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# - I can be placed before V (5) and X (10) to make 4 and 9.
# - X can be placed before L (50) and C (100) to make 40 and 90.
# - C can be placed before D (500) and M (1000) to make 400 and 900.
# - Given an integer, convert it to a roman numeral.

# %% [markdown]
# - Example 1:
#
# Input: num = 3
#
# Output: "III"
#
# Explanation: 3 is represented as 3 ones.
#
# - Example 2:
#
# Input: num = 58
#
# Output: "LVIII"
#
# Explanation: L = 50, V = 5, III = 3.
#
# - Example 3:
#
# Input: num = 1994
#
# Output: "MCMXCIV"
#
# Explanation: M = 1000, CM = 900, XC = 90 and IV = 4.A

# %%
# This code compairs every single cases that can occerr
# So it's code is long and dirty(because of 6 exeptions)
class Solution:
    def intToRoman(self, num: int) -> str:
        res = ""
        while num != 0:
            if num>=1000:
                res += "M"*(num//1000)
                num -= 1000*(num//1000)
            elif num>=500:
                if num//100 == 9:
                    res += "CM"
                    num -= 900
                else:
                    res += "D"
                    num -= 500
            elif num>=100:
                v = num//100
                if v == 4:
                    res += "CD"
                else:
                    res += "C"*v
                num -= 100*v
            elif num>=50:
                if num//10 == 9:
                    res += "XC"
                    num -= 90
                else:
                    res += "L"
                    num -= 50
            elif num>=10:
                v = num//10
                if v == 4:
                    res += "XL"
                else:
                    res += "X"*(num//10)
                num -= 10*v
            elif num>=5:
                if num == 9:
                    res+="IX"
                    num -= 9
                else:
                    res += "V"
                    num -= 5
            else:
                if num == 4:
                    res += "IV"
                else:
                    res += "I"*num
                num = 0
        return res

# %%
# by pniraj657(beats 99%) it is completly better than my code..simple and short!
class Solution:
    def intToRoman(self, num: int) -> str:
        # Creating Dictionary for Lookup
        num_map = {
            1: "I",
            5: "V",    4: "IV",
            10: "X",   9: "IX",
            50: "L",   40: "XL",
            100: "C",  90: "XC",
            500: "D",  400: "CD",
            1000: "M", 900: "CM",
        }
        
        # Result Variable
        r = ''
        
        
        for n in [1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1]:
            # If n in list then add the roman value to result variable
            while n <= num:
                r += num_map[n]
                num-=n
        return r

# %%
# unlike upper code it created every possible thing in num and just returned it(it was able because num should be between 1 and 3999)
class Solution:
    def intToRoman(self, num: int) -> str:
        M=["","M","MM","MMM"]
        C=["","C","CC","CCC","CD","D","DC","DCC","DCCC","CM"]
        X=["","X","XX","XXX","XL","L","LX","LXX","LXXX","XC"]
        I=["","I","II","III","IV","V","VI","VII","VIII","IX"]
        return M[num//1000]+C[num%1000//100]+X[num%1000%100//10]+I[num%1000%100%10]
